# %%
#include<iostream>
# Out:
#   Cell In[1], line 2
#     int main(){
#         ^
# SyntaxError: invalid syntax

# %%
int main(){
    std::cout << "Hello World" << std::endl;
}
# Out:
#   Cell In[1], line 1
#     int main(){
#         ^
# SyntaxError: invalid syntax
